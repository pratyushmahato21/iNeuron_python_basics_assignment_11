# %% [markdown]
# 1. Create an assert statement that throws an AssertionError if the variable spam is a negative integer.

# %%
spam= int(input('enter a number: '))
assert spam > 0, 'spam should be greater than 0'
# Out:
# enter a number: -7
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 spam= int(input('enter a number: '))
# ----> 2 assert spam > 0, 'spam should be greater than 0'
#
# AssertionError: spam should be greater than 0

# %% [markdown]
# 2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different (that is, 'hello' and 'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).

# %%
eggs=input('enter first word: ')
bacon= input('enter second word: ')

assert eggs.lower() == bacon.lower(), 'both are different'
# Out:
# enter first word: goodbye
# enter second word: GOODbye

# %% [markdown]
# 3. Create an assert statement that throws an AssertionError every time.

# %%
def assert_always():
    assert False, 'Always Shows Assertion Error'
assert_always()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 def assert_always():
#       2     assert False, 'Always Shows Assertion Error'
# ----> 3 assert_always()
#
# Input In [3], in assert_always()
#       1 def assert_always():
# ----> 2     assert False, 'Always Shows Assertion Error'
#
# AssertionError: Always Shows Assertion Error

# %% [markdown]
# 4. What are the two lines that must be present in your software in order to call logging.debug()?

# %%
import logging as lg
lg.basicConfig(filename = 'application_log.txt',level=lg.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# 5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?

# %%
import logging as lg
lg.basicConfig(filename = 'application_log.txt',level=lg.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')
lg.debug("Data Inserted Successfully")
lg.debug('Connection Closed Successfully')

# %%
file = open("./application_log.txt","r")
for record in file.readlines():
    print(record)
# Out:
#  2022-04-07 16:01:04,701 - DEBUG - diff parser start
#
#  2022-04-07 16:01:04,701 - DEBUG - line_lengths old: 2; new: 1
#
#  2022-04-07 16:01:04,701 - DEBUG - -> code[replace] old[1:2] new[1:1]
#
#  2022-04-07 16:01:04,701 - DEBUG - parse_part from 1 to 1 (to 0 in part parser)
#
#  2022-04-07 16:01:04,701 - DEBUG - diff parser end
#
#  2022-04-07 16:01:04,847 - DEBUG - diff parser start
#
#  2022-04-07 16:01:04,852 - DEBUG - line_lengths old: 1; new: 1
#
#  2022-04-07 16:01:04,852 - DEBUG - -> code[replace] old[1:1] new[1:1]
#
#  2022-04-07 16:01:04,852 - DEBUG - parse_part from 1 to 1 (to 0 in part parser)
#
#  2022-04-07 16:01:04,852 - DEBUG - diff parser end
#
#  2022-04-07 16:01:05,037 - DEBUG - diff parser start
#
#  2022-04-07 16:01:05,037 - DEBUG - line_lengths old: 1; new: 1
#
#  2022-04-07 16:01:05,037 - DEBUG - -> code[replace] old[1:1] new[1:1]
#
#  2022-04-07 16:01:05,042 - DEBUG - parse_part from 1 to 1 (to 0 in part parser)
#
# ...

# %% [markdown]
# 6. What are the five levels of logging?

# %% [markdown]
# Ans: The five levels of logging are CRITICAL:50 , ERROR:40 , WARNING:30 , INFO:20 , DEBUG:10 , NOTSET:0

# %% [markdown]
# 7. What line of code would you add to your software to disable all logging messages?

# %% [markdown]
# Ans: logging.disable = True

# %% [markdown]
# 8.Why is using logging messages better than using print() to display the same message?

# %% [markdown]
# Ans: logging is used to record all events like error, info, debug messages, timestamps. Logging will create a log file from which data can be easily extracted. In case of print statement we get no info, we get the output of only whta is written inside print statement

# %% [markdown]
# 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?

# %% [markdown]
# Ans:
# Step in - Step In button will cause the debugger to execute the next line of code and then pause again.
#
# Step Over - Step Over button will execute the next line of code, similar to the Step In button. However, if the next line of code is a function call, the Step Over button will “step over” the code in the function. The function’s code will be executed at full speed, and the debugger will pause as soon as the function call returns.
#
# Step out - Step Out button will cause the debugger to execute lines of code at full speed until it returns from the current function

# %% [markdown]
# 10.After you click Continue, when will the debugger stop ?

# %% [markdown]
# Ans: This will cause the program to continue running normally, without pausing for debugging untill it terminates or reaches a breakpoint.

# %% [markdown]
# 11. What is the concept of a breakpoint?

# %% [markdown]
# Ans: Breakpoint is an intentional stopping or pausing place in a program that causes the debugger to pause when the program execution reaches the line
